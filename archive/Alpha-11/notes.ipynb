# %% [markdown]
# Something's severly and totally going wrong here!
#
# This is what the 100M model generates after 500 epochs on CIFAR10 on 64px images (12 hours):
#
# ![408852433-a5540802-9f0c-4589-8dd5-f2b4dfebcb8c.png](attachment:5feae89c-8ff2-487b-8219-6219cccae8f3.png)
#
# And this is how cloneofsimo's 10M model behaves after 100 epochs on 32px images (~2hrs), without a VAE:
#
# ![sample_99_last.png](attachment:d43adf0e-adde-4ee0-8dd5-a4e879dfbe9e.png)

# %% [markdown]
# Good things is I finally have a baseline. The problem is that these two models are completely different:
# * DC-AE vs none
# * lognormal timestep sampling
# * almost same LR but vastly different model and batch size
# * text encoder versus simple label embedding
